# %% [markdown]
# # Table of Contents
# ## 01. Import Libraries
# ## 02. Import Data
# ## 03. Data Wrangling & Consistency Checks
# ## 04. Merging Datasets
# ## 05. Exporting Datasets

# %% [markdown]
# ## 01. Import Libraries

# %%
# importing libraries
import pandas as pd
import numpy as nm
import os

# %% [markdown]
# ## 02. Import Data

# %%
path = r'/Users/lianabulte/Career Foundry/2023 02 Instacart Basket Analysis'

# %%
df_customer = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# ## 03. Data Wrangling & Consistency Checks

# %%
# view columns in customer dataset
df_customer.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# size of customer dataset
df_customer.shape
# Out:
# (206209, 10)

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
# rename columns to be uniformed
df_customer.rename(columns = {'Surnam' : 'Last Name'}, inplace=True)
df_customer.rename(columns = {'First Name' : 'first_name'}, inplace=True)
df_customer.rename(columns = {'Gender' : 'gender'}, inplace=True)
df_customer.rename(columns = {'STATE' : 'state'}, inplace=True)
df_customer.rename(columns = {'Age' : 'age'}, inplace=True)
df_customer.rename(columns = {'Last Name' : 'last_name'}, inplace=True)

# %%
# verify renaming worked
df_customer.columns
# Out:
# Index(['user_id', 'first_name', 'last_name', 'gender', 'state', 'age',
#        'date_joined', 'n_dependants', 'fam_status', 'income'],
#       dtype='object')

# %%
# checking which columns have missing data 
df_customer.isnull().sum()
# Out:
# user_id             0
# first_name      11259
# last_name           0
# gender              0
# state               0
# age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %% [markdown]
# with first_name being the only column that has missing data i will choose to leave this untouched as the remaining columns are complete

# %%
df_customer_nan= df_customer[df_customer['first_name'].isnull()==True]

# %%
df_customer_nan
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, n_dependants, fam_status, income]
# Index: []

# %%
# checking for duplicates
df_customer_dups = df_customer.duplicated()

# %%
df_customer_dups
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 206204    False
# 206205    False
# 206206    False
# 206207    False
# 206208    False
# Length: 206209, dtype: bool

# %%
df_customer_dups.value_counts()
# Out:
# False    206209
# dtype: int64

# %% [markdown]
# there are no full duplicates in the customer dataset

# %%
# checking for mixed-type data in dataframe
for col in df_customer.columns.tolist():
  weird = (df_customer[[col]].applymap(type) != df_customer[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customer[weird]) > 0:
    print (col)
# Out:
# first_name

# %% [markdown]
# first_name column has mixed data type

# %%
# changing the column type of first_name to string
df_customer['first_name'] = df_customer['first_name'].astype('str')

# %%
# verify first_name column type has changed
df_customer['first_name'].dtype
# Out:
# dtype('O')

# %%
# checking for abnormalities in df 
df_customer.describe()
# Out:
#              user_id            age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# all int columns appear to be with no low or high abnormalities

# %%
# reviewing final form prior to merge
df_customer.head(15)
# Out:
#     user_id first_name last_name  gender           state  age date_joined  \
# 0     26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1     33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2     65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3    125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4    130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5    133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6    152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7    168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8     69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9     82820      Shawn     Chung    Male        Virginia   26    1/1/2017
# 10    26441     Gloria  Stafford  Female          Nevada   19    1/1/2017
# 11    33835      Roger     Casey    Male        Nebraska   45    1/1/2017
# ...

# %% [markdown]
# ## 04. Merging datasets

# %%
#import latest dataset for orders_products_merged
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated_2.pkl'))

# %%
# checking shape
ords_prods_merge.shape
# Out:
# (30328763, 24)

# %%
# checking table
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795        1             2                   3                  7
# 1    473747        1             3                   3                 12
# 2   2254736        1             4                   4                  7
# 3    431534        1             5                   4                 15
# 4   3367565        1             6                   2                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    21.0         196                  1          1
# 2                    29.0         196                  1          1
# 3                    28.0         196                  1          1
# 4                    19.0         196                  1          1
#
#   product_name  ...    price_range_loc     busiest_day  busiest_days  \
# ...

# %% [markdown]
# matches data that was exported in previous exercise

# %%
# review data types of dataframe
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30328763 entries, 0 to 30328762
# Data columns (total 24 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       int64
#  8   reordered               int64
#  9   product_name            object
#  10  aisle_id                int64
#  11  department_id           int64
#  12  prices                  float64
#  13  _merge                  category
#  14  price_range_loc         object
#  15  busiest_day             object
#  16  busiest_days            object
#  17  busiest_period_of_day   object
#  18  max_order               int64
#  19  loyalty_flag            object
#  20  avg_price               float64
# ...

# %% [markdown]
# 'user_id' is common key in both dataframes and will use this column to merge the two, and both are set at int64 data types

# %%
# merging df_customer with ords_prods_merge 
df_merged = pd.merge(ords_prods_merge, df_customer, on = 'user_id', how = 'outer')

# %%
# checking new columns added 
df_merged.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2398795.0        1           2.0                 3.0                7.0
# 1   473747.0        1           3.0                 3.0               12.0
# 2  2254736.0        1           4.0                 4.0                7.0
# 3   431534.0        1           5.0                 4.0               15.0
# 4  3367565.0        1           6.0                 2.0                7.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0       196.0                1.0        1.0
# 1                    21.0       196.0                1.0        1.0
# 2                    29.0       196.0                1.0        1.0
# 3                    28.0       196.0                1.0        1.0
# 4                    19.0       196.0                1.0        1.0
#
#   product_name  ...   order_frequency_flag  first_name  last_name  gender  \
# ...

# %%
#Checking value counts
df_merged['_merge'].value_counts()
# Out:
# both          30328763
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# columns have been added succesfully - ready to export

# %% [markdown]
# ## 05. Exporting Dataset

# %%
# Export data to pkl
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_all.pkl'))
